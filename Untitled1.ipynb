# %%
import requests
import json
URL = "https://test-api-for-giggles.herokuapp.com/"
response = requests.get(URL)
response.raise_for_status
json.loads(response.content.decode("utf-8"))
# Out:
# {'filters_avaliable': ['blur',
#   'contour',
#   'detail',
#   'edge_enhance',
#   'edge_enhance_more',
#   'emboss',
#   'find_edges',
#   'sharpen',
#   'smooth',
#   'smooth_more'],
#  'usage': {'URL': '/<filter_available>?', 'http_method': 'POST'}}

# %%
file = {"image":open("sample.jpg","rb")}
headers = {"type":"multipart/image"}

filter = "contour"

response = requests.post(f"{URL}/{filter}", headers=headers,files=file)
response.raise_for_status
# Out:
# <bound method Response.raise_for_status of <Response [200]>>

# %%
from PIL import Image
import io

image = Image.open(io.BytesIO(response.content))
image.save("response.jpg","JPEG")

image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x439 at 0x18E1B6E1F00>
